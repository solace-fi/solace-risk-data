# %% [markdown]
# ### This is a notebook that walks through the steps to create the temporal data sheet

# %% [markdown]
# ### Step 1: Import requirements:

# %%
import defi.defi_tools as dft
import pandas as pd
import io
import requests
from datetime import datetime, date 
import json

# %% [markdown]
# ### Step 2: Create a dataframe from llama API with the necessary attributes

# %%
##llama API
df = dft.getProtocols()
df['address']=df['address'].str.lower()

## Remove unnecessary* factors
factors_needed=df.filter(['name','address','symbol','audits','category','chains','oracles','tvl','forkedFrom','slug'], axis=1).reset_index()
#Create a new SolaceID
factors_needed['SolaceID'] = factors_needed['name'].str.split(' ').str[0] 
factors_needed['SolaceID']=factors_needed['SolaceID'].str.lower()

# Array with only ethereum protocols
ethProtocols=[]
for i in factors_needed['chains']:
    if 'Ethereum' in i:
        ethProtocols.append(i)

#First 5 values for demonstration
pd.set_option('display.max_rows', None, 'display.max_columns', None)
factors_needed.head()
# Out:
#              name                                     address symbol audits  \
# 0           Curve  0xd533a949740bb3306d119cc777fa900ba034cd52    CRV      2
# 1        MakerDAO  0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2    MKR      2
# 2  Convex Finance  0x4e3fbd56cd56c3e72c1403e103b45db9da5b9d2b    CVX      2
# 3            AAVE  0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9   AAVE      2
# 4            WBTC  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599   WBTC      2
#
#   category                                             chains      oracles  \
# 0    Dexes  [Ethereum, Avalanche, Fantom, Polygon, Arbitru...           []
# 1      CDP                                         [Ethereum]      [Maker]
# 2    Yield                                         [Ethereum]          NaN
# 3  Lending                     [Ethereum, Avalanche, Polygon]  [Chainlink]
# 4   Bridge                                         [Ethereum]           []
#
#             tvl forkedFrom            slug  SolaceID
# 0  1.976971e+10        NaN           curve     curve
# 1  1.754983e+10        NaN        makerdao  makerdao
# 2  1.365008e+10        NaN  convex-finance    convex
# 3  1.359565e+10        NaN            aave      aave
# 4  1.160865e+10        NaN            wbtc      wbtc

# %% [markdown]
# ### Step 3: Get Zapper Api data from this endpoint:
#
# Zapper protocol attributes:
#
# https://api.zapper.fi/v1/apps?api_key=96e0cc51-a62e-42ca-acee-910ea7d2a241

# %%
## Attribute Endpoint
url_attributes = r'https://api.zapper.fi/v1/apps?api_key=96e0cc51-a62e-42ca-acee-910ea7d2a241' 
urlData_attributes = requests.get(url_attributes).content
zapperAttributes = pd.read_json(io.StringIO(urlData_attributes.decode('utf-8')))

# Open reference table to create Solace category 
f = open('../governance/reference/mappingTablesSolace.json')
lookupTables = json.loads(f.read())
f.close()
#reference=pd.read_json('../governance/reference/mappingTablesSolace.json')
categories=pd.DataFrame(lookupTables['categorySolaceLookup'])

def lookup_categorySolace(category):
    if pd.isna(category):
        return 'unknown'
    elif category not in list(categories['category']):
        return 'other'
    else:
        return category

zapperAttributes['tags']=zapperAttributes['tags'].str.get(0)
zapperAttributes['categorySolace'] = zapperAttributes['tags'].apply(lookup_categorySolace)

## Merge attrubutes from both llama and zapper using different id from Zapper, Llama and Solace
zapperAttributes['SolaceID'] = zapperAttributes['name'].str.split(' ').str[0]
zapperAttributes['SolaceID']=zapperAttributes['SolaceID'].str.lower()

# First merging on id from zapper and id from llama
combinedTable1=pd.merge(zapperAttributes[['id','tags','name','categorySolace','SolaceID']],factors_needed,left_on='id', right_on='slug', how='left')

combinedTable1=combinedTable1.drop(columns=['SolaceID_y'])
combinedTable1=combinedTable1.rename(columns={'SolaceID_x':'SolaceID'})
# Now merging again on the SolaceID to captue more data points
combinedTable2=pd.merge(combinedTable1,factors_needed,left_on='SolaceID', right_on='SolaceID', how='left')
# Combine both table into one containing all the captured data points
combinedTable2.address_x.fillna(combinedTable2.address_y,inplace=True)

combinedTable2.name_x.fillna(combinedTable2.name_y,inplace=True)

combinedTable2.symbol_x.fillna(combinedTable2.symbol_y,inplace=True)

combinedTable2.chains_x.fillna(combinedTable2.chains_y,inplace=True)

combinedTable2.oracles_x.fillna(combinedTable2.oracles_y,inplace=True)

combinedTable2.tvl_x.fillna(combinedTable2.tvl_y,inplace=True)

combinedTable2.audits_x.fillna(combinedTable2.audits_y,inplace=True)

combinedTable2=combinedTable2.rename(columns={'address_x':'address','name_x':'name','symbol_x':'symbol','chains_x':'chains','oracles_x':'oracles','tvl_x':'tvl','audits_x':'audits'})

combinedTable2.head()
# Out:
#                    id              tags                name    categorySolace  \
# 0            aave-amm           lending            Aave AMM           lending
# 1  aave-safety-module    liquidity-pool  Aave Safety Module    liquidity-pool
# 2                aave           lending                Aave           lending
# 3             aave-v2           lending             Aave V2           lending
# 4          aavegotchi  yield-aggregator          Aavegotchi  yield-aggregator
#
#      SolaceID      name_y                                     address symbol  \
# 0        aave         NaN  0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9   AAVE
# 1        aave         NaN  0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9   AAVE
# 2        aave        AAVE  0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9   AAVE
# 3        aave         NaN  0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9   AAVE
# 4  aavegotchi  Aavegotchi  0x3f382dbd960e3a9bbceae22651e88158d2791550   GHST
#
#   audits category_x                          chains      oracles  \
# 0      2        NaN  [Ethereum, Avalanche, Polygon]  [Chainlink]
# 1      2        NaN  [Ethereum, Avalanche, Polygon]  [Chainlink]
# 2      2    Lending  [Ethereum, Avalanche, Polygon]  [Chainlink]
# 3      2        NaN  [Ethereum, Avalanche, Polygon]  [Chainlink]
# 4      2     Gaming             [Polygon, Ethereum]          NaN
#
#             tvl forkedFrom_x      slug_x        name  \
# 0  1.359565e+10          NaN         NaN        AAVE
# 1  1.359565e+10          NaN         NaN        AAVE
# 2  1.359565e+10          NaN        aave        AAVE
# 3  1.359565e+10          NaN         NaN        AAVE
# 4  1.754204e+07          NaN  aavegotchi  Aavegotchi
#
#                                     address_y symbol_y audits_y category_y  \
# 0  0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9     AAVE        2    Lending
# 1  0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9     AAVE        2    Lending
# 2  0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9     AAVE        2    Lending
# 3  0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9     AAVE        2    Lending
# 4  0x3f382dbd960e3a9bbceae22651e88158d2791550     GHST        2     Gaming
#
#                          chains_y    oracles_y         tvl_y forkedFrom_y  \
# 0  [Ethereum, Avalanche, Polygon]  [Chainlink]  1.359565e+10          NaN
# 1  [Ethereum, Avalanche, Polygon]  [Chainlink]  1.359565e+10          NaN
# 2  [Ethereum, Avalanche, Polygon]  [Chainlink]  1.359565e+10          NaN
# 3  [Ethereum, Avalanche, Polygon]  [Chainlink]  1.359565e+10          NaN
# 4             [Polygon, Ethereum]          NaN  1.754204e+07          NaN
#
#        slug_y
# 0        aave
# 1        aave
# 2        aave
# 3        aave
# 4  aavegotchi

# %% [markdown]
# ### Step 4: Get launch dates from Dune and merge with Table *WIP

# %%
DuneData=pd.read_csv('../temporalDB/launch_dates.csv',names=["address", "LaunchDate"])
finalTable = pd.merge(combinedTable2,DuneData,left_on='address', right_on='address', how='left')
finalTable=finalTable.rename(columns={'id':'appId'})
#Skip these statements if you want all protocols
finalTable=finalTable.loc[finalTable['chains'].isin(ethProtocols)]
finalTable = finalTable.loc[:,~finalTable.columns.duplicated()]
finalTable=finalTable.filter(['appId','tags','name','categorySolace','SolaceID','address','symbol','audits','chains','oracles','tvl','LaunchDate'], axis=1)

finalTable
# Out:
#                       appId                     tags                    name  \
# 0                  aave-amm                  lending                Aave AMM
# 1        aave-safety-module           liquidity-pool      Aave Safety Module
# 2                      aave                  lending                    Aave
# 3                   aave-v2                  lending                 Aave V2
# 4                aavegotchi         yield-aggregator              Aavegotchi
# 5               abracadabra                  lending             Abracadabra
# 7                  alchemix                  lending                Alchemix
# 8                    alkemi                  lending          Alkemi Network
# 9          alpha-tokenomics          elastic-finance        Alpha Tokenomics
# 10                 alpha-v1                  lending                   Alpha
# 11                 alpha-v2                  lending                Alpha V2
# 16                      apy         yield-aggregator                     APY
# 17                     arcx         yield-aggregator                    ARCx
# 18                    armor                insurance                   Armor
# 20               b-protocol                  lending              B.Protocol
# 21                   badger         yield-aggregator                  Badger
# 22              balancer-v1           liquidity-pool                Balancer
# 23              balancer-v2           liquidity-pool             Balancer V2
# 24                   bancor           liquidity-pool                  Bancor
# 25                      bao           liquidity-pool                     Bao
# 26               barnbridge  tokenized-risk-protocol              BarnBridge
# 27   barnbridge-smart-yield  tokenized-risk-protocol  BarnBridge Smart Yield
# 34                     bent                      NaN            Bent Finance
# 39                 compound                  lending                Compound
# 40                   convex         yield-aggregator                  Convex
# 41                    cream                  lending                   Cream
# 42                  cryptex           liquidity-pool                 Cryptex
# 43                    curve           liquidity-pool                   Curve
# 48                defi-swap           liquidity-pool               DeFi Swap
# 49                defi-swap           liquidity-pool               DeFi Swap
# 50                defi-swap           liquidity-pool               DeFi Swap
# 51                defi-swap           liquidity-pool               DeFi Swap
# 52                defisaver                  lending               DefiSaver
# 53                derivadex              derivatives               DerivaDEX
# 54                deversifi                 exchange               DeversiFi
# 55                   dforce         yield-aggregator                  dForce
# 57                   dhedge         asset-management                  dHedge
# 59                     dodo           liquidity-pool                    Dodo
# 60                    dopex                  options                   Dopex
# 61                     dydx           margin-trading                    dYdX
# 62                    88mph                  lending                   88mph
# 63                 88mph-v3                  lending                88mph V3
# 64                  element                  lending                 Element
# 70                      fei         asset-management                     Fei
# 71           float-protocol         asset-management                   Float
# 72           float-protocol         asset-management                   Float
# 73                     frax         asset-management                    Frax
# 76             governor-dao           liquidity-pool            Governor DAO
# 78                      gro                  lending                     Gro
# 79                  harvest         yield-aggregator                 Harvest
# 81                    hegic                  options                   Hegic
# 83                      hop                      NaN                     Hop
# 84          hundred-finance                  lending         Hundred Finance
# 85                     idle         yield-aggregator                    Idle
# 86                 illuvium                   gaming                Illuvium
# 87               index-coop            asset-indexes              Index Coop
# 88                  indexed             fund-manager                 Indexed
# 89                  inverse         yield-aggregator         Inverse Finance
# 90                     iron          elastic-finance                    Iron
# 92                iron-bank                  lending               Iron Bank
# 93                iron-bank                  lending               Iron Bank
# 95             keep-network             fund-manager            Keep Network
# 96               keeper-dao         yield-aggregator               KeeperDAO
# 98                 klondike             fund-manager                Klondike
# 104                 liquity                  lending                 Liquity
# 105               looksrare                      NaN               LOOKSRARE
# 106                loopring                 exchange                Loopring
# 108                    lyra                  options                    Lyra
# 110                   maple                  lending                   Maple
# 111                  mirror           liquidity-pool                  Mirror
# 112               mooniswap                 exchange               Mooniswap
# 114                 mstable         asset-management                 mStable
# 116            nexus-mutual                      NaN            Nexus Mutual
# 117            nexus-mutual                      NaN            Nexus Mutual
# 119                   nft20                      NaN                   NFT20
# 120                    nftx                      NaN                    NFTX
# 121           nsure-network                insurance                   Nsure
# 122                 olympus          elastic-finance                 Olympus
# 123                    ondo         yield-aggregator            Ondo Finance
# 124                   1inch                 exchange                   1inch
# 125                     onx                  lending                     OnX
# 126           opium-network              derivatives                   Opium
# 127                    opyn                  options                    Opyn
# 128                  origin               stablecoin                  Origin
# 129          orion-protocol                 exchange                   Orion
# 130          orion-protocol                 exchange                   Orion
# 135      perpetual-protocol                 exchange               Perpetual
# 136                  pickle         yield-aggregator                  Pickle
# 137                 pie-dao           liquidity-pool                  PieDAO
# 140            pooltogether          no-loss-lottery            PoolTogether
# 141         pooltogether-v4          no-loss-lottery         PoolTogether V4
# 142                popsicle           liquidity-pool                Popsicle
# 143               powerpool            asset-bundles               PowerPool
# 147                 railgun                 exchange                 Railgun
# 149                    rari             fund-manager            Rari Capital
# 150               rari-fuse           liquidity-pool               Rari Fuse
# 153         redacted-cartel          elastic-finance         Redacted Cartel
# 154                reflexer                  lending                Reflexer
# 156                  ribbon         yield-aggregator                  Ribbon
# 157               ribbon-v2         yield-aggregator               Ribbon V2
# 159                 sablier                  payroll                 Sablier
# 160                  saddle           liquidity-pool                  Saddle
# 163              shapeshift                 exchange              Shapeshift
# 165                   shell           liquidity-pool                   Shell
# 169                snowswap           liquidity-pool                SnowSwap
# 173                   squid          elastic-finance                SquidDao
# 177               sushiswap           liquidity-pool               Sushiswap
# 178      sushiswap-bentobox                  lending      SushiSwap BentoBox
# 179         sushiswap-kashi                  lending         SushiSwap Kashi
# 180                   swapr           liquidity-pool                   Swapr
# 181                  swerve           liquidity-pool                  Swerve
# 182                  synlev           liquidity-pool                  SynLev
# 183               synthetix           liquidity-pool               Synthetix
# 189               the-graph           liquidity-pool               The Graph
# 190               the-graph           liquidity-pool               The Graph
# 191                 tokemak           liquidity-pool                 Tokemak
# 192                tokenlon         asset-management                Tokenlon
# 196            tornado-cash           infrastructure            Tornado Cash
# 197            tornado-cash           infrastructure            Tornado Cash
# 200                  truefi                  lending                  TrueFi
# 202                  unagii         yield-aggregator                  Unagii
# 203                 uniswap                 exchange                 Uniswap
# 204              uniswap-v2           liquidity-pool              Uniswap V2
# 205              uniswap-v3           liquidity-pool              Uniswap V3
# 206                    unit                  lending                    Unit
# 207                universe                      NaN                Universe
# 208                universe                      NaN                Universe
# 211                  vesper         yield-aggregator                  Vesper
# 215                 wepiggy                  lending                 WePiggy
# 216              wonderland          elastic-finance              Wonderland
# 217                  xsigma           liquidity-pool                  xSigma
# 218                  xtoken         asset-management                  xToken
# 219                     yam         asset-management                     Yam
# 220                   yaxis         yield-aggregator                   yAxis
# 221                   yearn         yield-aggregator                   Yearn
# 225                    zlot         yield-aggregator                    zLOT
#
#        categorySolace      SolaceID  \
# 0             lending          aave
# 1      liquidity-pool          aave
# 2             lending          aave
# 3             lending          aave
# 4    yield-aggregator    aavegotchi
# 5             lending   abracadabra
# 7             lending      alchemix
# 8             lending        alkemi
# 9               other         alpha
# 10            lending         alpha
# 11            lending         alpha
# 16   yield-aggregator           apy
# 17   yield-aggregator          arcx
# 18              other         armor
# 20            lending    b.protocol
# 21   yield-aggregator        badger
# 22     liquidity-pool      balancer
# 23     liquidity-pool      balancer
# 24     liquidity-pool        bancor
# 25     liquidity-pool           bao
# 26              other    barnbridge
# 27              other    barnbridge
# 34            unknown          bent
# 39            lending      compound
# 40   yield-aggregator        convex
# 41            lending         cream
# 42     liquidity-pool       cryptex
# 43     liquidity-pool         curve
# 48     liquidity-pool          defi
# 49     liquidity-pool          defi
# 50     liquidity-pool          defi
# 51     liquidity-pool          defi
# 52            lending     defisaver
# 53              other     derivadex
# 54           exchange     deversifi
# 55   yield-aggregator        dforce
# 57   asset-management        dhedge
# 59     liquidity-pool          dodo
# 60              other         dopex
# 61              other          dydx
# 62            lending         88mph
# 63            lending         88mph
# 64            lending       element
# 70   asset-management           fei
# 71   asset-management         float
# 72   asset-management         float
# 73   asset-management          frax
# 76     liquidity-pool      governor
# 78            lending           gro
# 79   yield-aggregator       harvest
# 81              other         hegic
# 83            unknown           hop
# 84            lending       hundred
# 85   yield-aggregator          idle
# 86              other      illuvium
# 87              other         index
# 88              other       indexed
# 89   yield-aggregator       inverse
# 90              other          iron
# 92            lending          iron
# 93            lending          iron
# 95              other          keep
# 96   yield-aggregator     keeperdao
# 98              other      klondike
# 104           lending       liquity
# 105           unknown     looksrare
# 106          exchange      loopring
# 108             other          lyra
# 110           lending         maple
# 111    liquidity-pool        mirror
# 112          exchange     mooniswap
# 114  asset-management       mstable
# 116           unknown         nexus
# 117           unknown         nexus
# 119           unknown         nft20
# 120           unknown          nftx
# 121             other         nsure
# 122             other       olympus
# 123  yield-aggregator          ondo
# 124          exchange         1inch
# 125           lending           onx
# 126             other         opium
# 127             other          opyn
# 128             other        origin
# 129          exchange         orion
# 130          exchange         orion
# 135          exchange     perpetual
# 136  yield-aggregator        pickle
# 137    liquidity-pool        piedao
# 140             other  pooltogether
# 141             other  pooltogether
# 142    liquidity-pool      popsicle
# 143             other     powerpool
# 147          exchange       railgun
# 149             other          rari
# 150    liquidity-pool          rari
# 153             other      redacted
# 154           lending      reflexer
# 156  yield-aggregator        ribbon
# 157  yield-aggregator        ribbon
# 159             other       sablier
# 160    liquidity-pool        saddle
# 163          exchange    shapeshift
# 165    liquidity-pool         shell
# 169    liquidity-pool      snowswap
# 173             other      squiddao
# 177    liquidity-pool     sushiswap
# 178           lending     sushiswap
# 179           lending     sushiswap
# 180    liquidity-pool         swapr
# 181    liquidity-pool        swerve
# 182    liquidity-pool        synlev
# 183    liquidity-pool     synthetix
# 189    liquidity-pool           the
# 190    liquidity-pool           the
# 191    liquidity-pool       tokemak
# 192  asset-management      tokenlon
# 196             other       tornado
# 197             other       tornado
# 200           lending        truefi
# 202  yield-aggregator        unagii
# 203          exchange       uniswap
# 204    liquidity-pool       uniswap
# 205    liquidity-pool       uniswap
# 206           lending          unit
# 207           unknown      universe
# 208           unknown      universe
# 211  yield-aggregator        vesper
# 215           lending       wepiggy
# 216             other    wonderland
# 217    liquidity-pool        xsigma
# 218  asset-management        xtoken
# 219  asset-management           yam
# 220  yield-aggregator         yaxis
# 221  yield-aggregator         yearn
# 225  yield-aggregator          zlot
#
#                                                address  symbol audits  \
# 0           0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9    AAVE      2
# 1           0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9    AAVE      2
# 2           0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9    AAVE      2
# 3           0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9    AAVE      2
# 4           0x3f382dbd960e3a9bbceae22651e88158d2791550    GHST      2
# 5           0x090185f2135308bad17527004364ebcc2d37e5f6   SPELL      2
# 7           0xdbdb4d16eda451d0503b854cf79d55697f90c8df    ALCX      2
# 8           0x6c16119b20fa52600230f074b349da3cb861a7e3     ALK      2
# 9           0xa1faa113cbe53436df28ff0aee54275c13b40975   ALPHA      2
# 10          0xa1faa113cbe53436df28ff0aee54275c13b40975   ALPHA      2
# 11          0xa1faa113cbe53436df28ff0aee54275c13b40975   ALPHA      2
# 16          0x95a4492f028aa1fd432ea71146b433e7b4446611     APY      2
# 17      eth:0x1321f1f1aa541a56c31682c57b80ecfccd9bb288    ARCx      0
# 18          0x1337def16f9b486faed0293eb623dc8395dfe46a   ARMOR      0
# 20          0xbbbbbbb5aa847a2003fbc6b5c16df0bd1e725f61    BPRO      2
# 21          0x3472a5a71965499acd81997a54bba8d852c6e53d  BADGER      2
# 22          0xba100000625a3754423978a60c9317c58a424e3d     BAL      2
# 23          0xba100000625a3754423978a60c9317c58a424e3d     BAL      2
# 24          0x1f573d6fb3f13d689ff844b4ce37794d79a7ff1c     BNT      2
# 25          0x374cb8c27130e2c9e04f44303f3c8351b9de61c1     BAO      0
# 26          0x0391d2021f89dc339f60fff84546ea23e337750f    BOND      2
# 27          0x0391d2021f89dc339f60fff84546ea23e337750f    BOND      2
# 34          0x01597e397605bf280674bf292623460b4204c375    BENT      2
# 39          0xc00e94cb662c3520282e6f5717214004a7f26888    COMP      2
# 40          0x4e3fbd56cd56c3e72c1403e103b45db9da5b9d2
xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f     SNX      2
# 189         0x3845badade8e6dff049820680d1f14bd3903a5d0    SAND      0
# 190         0x3b484b82567a09e2588a13d54d032153f0c0aee0     SOS      2
# 191         0x2e9d63788249371f1dfc918a52f8d799f4a38c94    TOKE      2
# 192         0x0000000000095413afc295d19edeb1ad7b71c952     LON      2
# 196         0x77777feddddffc19ff86db637967013e6c6a116c    TORN      2
# 197         0x77777feddddffc19ff86db637967013e6c6a116c    TORN      2
# 200         0x4c19596f5aaff459fa38b0f7ed92f11ae6543784     TRU      2
# 202                                                  -       -      2
# 203         0x1f9840a85d5af5bf1d1762f925bdaddc4201f984     UNI      2
# 204         0x1f9840a85d5af5bf1d1762f925bdaddc4201f984     UNI      2
# 205         0x1f9840a85d5af5bf1d1762f925bdaddc4201f984     UNI      2
# 206         0x92e187a03b6cd19cb6af293ba17f2745fd2357d5    DUCK      2
# 207                                               None       -      2
# 208        0x618679df9efcd19694bb1daa8d00718eacfa2883      XYZ      2
# 211         0x1b40183efb4dd766f11bda7a7c3ad8982e998421     VSP      2
# 215         0x6f620ec89b8479e97a6985792d0c64f237566746     WPC      2
# 216    avax:0xb54f16fb19478766a268f172c9480f8da1a7c9c3    TIME      0
# 217         0x7777777777697cfeecf846a76326da79cc606517     SIG      0
# 218         0x7f3edcdd180dbe4819bd98fee8929b5cedb3adeb     XTK      2
# 219         0x0aacfbec6a24756c20d41914f2caba817c0d8521     YAM      3
# 220         0x0ada190c81b814548ddc2f6adc4a689ce7c1fe73   YAXIS      2
# 221         0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e     YFI      1
# 225         0xa8e7ad77c60ee6f30bac54e2e7c0617bd7b5a03e    zLot      0
#
#                                                 chains            oracles  \
# 0                       [Ethereum, Avalanche, Polygon]        [Chainlink]
# 1                       [Ethereum, Avalanche, Polygon]        [Chainlink]
# 2                       [Ethereum, Avalanche, Polygon]        [Chainlink]
# 3                       [Ethereum, Avalanche, Polygon]        [Chainlink]
# 4                                  [Polygon, Ethereum]                NaN
# 5              [Ethereum, Arbitrum, Fantom, Avalanche]        [Chainlink]
# 7                                           [Ethereum]                 []
# 8                                           [Ethereum]        [Chainlink]
# 9                       [Avalanche, Ethereum, Binance]  [Band, Chainlink]
# 10                      [Avalanche, Ethereum, Binance]  [Band, Chainlink]
# 11                      [Avalanche, Ethereum, Binance]  [Band, Chainlink]
# 16                                          [Ethereum]        [Chainlink]
# 17                                          [Ethereum]                NaN
# 18                                          [Ethereum]                NaN
# 20                        [Ethereum, Fantom, Arbitrum]        [Chainlink]
# 21                       [Ethereum, Arbitrum, Binance]                 []
# 22                       [Ethereum, Polygon, Arbitrum]                NaN
# 23                       [Ethereum, Polygon, Arbitrum]                NaN
# 24                                          [Ethereum]        [Chainlink]
# 25                                    [Ethereum, xDai]                NaN
# 26                      [Ethereum, Polygon, Avalanche]        [Chainlink]
# 27                      [Ethereum, Polygon, Avalanche]        [Chainlink]
# 34                                          [Ethereum]                NaN
# 39                                          [Ethereum]        [Chainlink]
# 40                                          [Ethereum]                NaN
# 41                        [Binance, Ethereum, Polygon]  [Chainlink, Band]
# 42                                          [Ethereum]        [Chainlink]
# 43   [Ethereum, Avalanche, Fantom, Polygon, Arbitru...                 []
# 48                                          [Ethereum]                NaN
# 49                                          [Ethereum]                NaN
# 50                                          [Ethereum]                NaN
# 51                                          [Ethereum]        [Chainlink]
# 52                                          [Ethereum]                NaN
# 53                                          [Ethereum]                NaN
# 54                                          [Ethereum]                NaN
# 55             [Ethereum, Arbitrum, Binance, Optimism]  [Chainlink, Band]
# 57                       [Ethereum, Polygon, Optimism]                NaN
# 59      [Ethereum, Binance, Polygon, Aurora, Arbitrum]        [Chainlink]
# 60            [Arbitrum, Avalanche, Binance, Ethereum]                NaN
# 61                                          [Ethereum]        [Chainlink]
# 62              [Ethereum, Fantom, Polygon, Avalanche]        [Chainlink]
# 63              [Ethereum, Fantom, Polygon, Avalanche]        [Chainlink]
# 64                                          [Ethereum]                NaN
# 70                                          [Ethereum]        [Chainlink]
# 71                                          [Ethereum]                NaN
# 72                                          [Ethereum]        [Chainlink]
# 73                                  [Ethereum, Fantom]  [Chainlink, TWAP]
# 76                                          [Ethereum]                NaN
# 78                               [Ethereum, Avalanche]                NaN
# 79                        [Ethereum, Polygon, Binance]                NaN
# 81                                          [Ethereum]                NaN
# 83       [Ethereum, Arbitrum, Polygon, Optimism, xDai]                NaN
# 84    [Fantom, Arbitrum, Harmony, Moonriver, Ethereum]        [Chainlink]
# 85                                 [Ethereum, Polygon]        [Chainlink]
# 86                                          [Ethereum]                NaN
# 87                                          [Ethereum]                NaN
# 88                                          [Ethereum]                NaN
# 89                                          [Ethereum]                NaN
# 90                       [Ethereum, Avalanche, Fantom]        [Chainlink]
# 92                       [Ethereum, Avalanche, Fantom]        [Chainlink]
# 93                       [Ethereum, Avalanche, Fantom]        [Chainlink]
# 95                                          [Ethereum]            [Maker]
# 96                                          [Ethereum]                NaN
# 98                                          [Ethereum]                NaN
# 104                                         [Ethereum]        [Chainlink]
# 105                                         [Ethereum]                NaN
# 106                                         [Ethereum]  [Chainlink, Band]
# 108                               [Optimism, Ethereum]        [Chainlink]
# 110                                         [Ethereum]                NaN
# 111                                  [Terra, Ethereum]             [Band]
# 112                                         [Ethereum]                NaN
# 114                                [Ethereum, Polygon]                NaN
# 116                                         [Ethereum]        [Chainlink]
# 117                                         [Ethereum]        [Chainlink]
# 119                                [Ethereum, Polygon]                NaN
# 120                                         [Ethereum]                NaN
# 121                                         [Ethereum]        [Chainlink]
# 122                                         [Ethereum]                NaN
# 123                                         [Ethereum]                NaN
# 124                                         [Ethereum]        [Chainlink]
# 125                                         [Ethereum]                NaN
# 126                       [Ethereum, Polygon, Binance]                NaN
# 127                              [Ethereum, Avalanche]        [Chainlink]
# 128                                         [Ethereum]                NaN
# 129                                [Ethereum, Binance]                NaN
# 130                                [Ethereum, Binance]                NaN
# 135                         [xDai, Optimism, Ethereum]        [Chainlink]
# 136  [Ethereum, Arbitrum, Aurora, Polygon, Moonrive...                NaN
# 137                                         [Ethereum]                NaN
# 140      [Ethereum, Polygon, Celo, Avalanche, Binance]        [Chainlink]
# 141      [Ethereum, Polygon, Celo, Avalanche, Binance]        [Chainlink]
# 142                        [Fantom, Binance, Ethereum]                NaN
# 143                                [Ethereum, Binance]                NaN
# 147                       [Ethereum, Binance, Polygon]                NaN
# 149                                         [Ethereum]        [Chainlink]
# 150                                         [Ethereum]        [Chainlink]
# 153                                         [Ethereum]                NaN
# 154                                         [Ethereum]        [Chainlink]
# 156              [Ethereum, Avalanche, Aurora, Solana]                NaN
# 157              [Ethereum, Avalanche, Aurora, Solana]                NaN
# 159                                         [Ethereum]                NaN
# 160             [Ethereum, Fantom, Arbitrum, Optimism]                NaN
# 163                                         [Ethereum]                NaN
# 165                                         [Ethereum]                NaN
# 169                                [Ethereum, Polygon]        [Chainlink]
# 173                                         [Ethereum]                NaN
# 177  [Ethereum, Arbitrum, Polygon, Fantom, Avalanch...                 []
# 178  [Ethereum, Arbitrum, Polygon, Fantom, Avalanch...                 []
# 179  [Ethereum, Arbitrum, Polygon, Fantom, Avalanch...                 []
# 180                         [xDai, Arbitrum, Ethereum]                NaN
# 181                                         [Ethereum]                NaN
# 182                                         [Ethereum]                NaN
# 183                               [Ethereum, Optimism]        [Chainlink]
# 189                                [Ethereum, Polygon]                NaN
# 190                                         [Ethereum]                NaN
# 191                                         [Ethereum]                NaN
# 192                                         [Ethereum]                NaN
# 196                                         [Ethereum]                 []
# 197                                         [Ethereum]                 []
# 200                                         [Ethereum]                NaN
# 202                                         [Ethereum]                NaN
# 203            [Ethereum, Polygon, Arbitrum, Optimism]                 []
# 204            [Ethereum, Polygon, Arbitrum, Optimism]                 []
# 205            [Ethereum, Polygon, Arbitrum, Optimism]                 []
# 206                                         [Ethereum]                NaN
# 207                                [Ethereum, Polygon]                NaN
# 208                                         [Ethereum]                NaN
# 211                                         [Ethereum]        [Chainlink]
# 215  [Ethereum, Binance, OKExChain, Arbitrum, Optim...        [Chainlink]
# 216                              [Avalanche, Ethereum]                NaN
# 217                                         [Ethereum]                NaN
# 218                                         [Ethereum]                NaN
# 219                                         [Ethereum]                NaN
# 220                                         [Ethereum]                NaN
# 221                                 [Ethereum, Fantom]                NaN
# 225                                         [Ethereum]                NaN
#
#               tvl         LaunchDate
# 0    1.359565e+10   2020-09-24 18:06
# 1    1.359565e+10   2020-09-24 18:06
# 2    1.359565e+10   2020-09-24 18:06
# 3    1.359565e+10   2020-09-24 18:06
# 4    1.754204e+07                NaN
# 5    3.130727e+09   2021-05-17 22:10
# 7    9.604898e+08   2021-02-27 04:28
# 8    9.860368e+06   2021-09-02 17:35
# 9    8.278031e+08   2020-09-27 09:10
# 10   8.278031e+08   2020-09-27 09:10
# 11   8.278031e+08   2020-09-27 09:10
# 16   1.910854e+07   2020-11-05 02:58
# 17   0.000000e+00                NaN
# 18   5.151683e+08   2021-01-22 21:23
# 20   2.087972e+08   2021-04-22 07:24
# 21   8.837397e+08   2020-11-28 17:32
# 22   3.326251e+09   2020-06-20 01:32
# 23   3.326251e+09   2020-06-20 01:32
# 24   1.166352e+09   2017-06-10 16:02
# 25   4.841032e+07   2020-12-01 19:26
# 26   1.315753e+07   2020-09-07 15:55
# 27   1.315753e+07   2020-09-07 15:55
# 34   6.219070e+07                NaN
# 39   7.240576e+09   2020-03-04 00:08
# 40   1.365008e+10   2021-05-17 09:08
# 41   4.483840e+08   2020-08-04 15:06
# 42   9.852366e+06   2021-04-06 04:21
# 43   1.976971e+10   2020-08-12 22:17
# 48   5.510571e+07   2018-11-14 09:11
# 159  2.641545e+08                NaN
# 160  2.531374e+08                NaN
# 163  0.000000e+00   2019-03-26 22:24
# 165  1.588842e+07                NaN
# 169  2.140848e+06   2020-10-08 07:37
# 173  0.000000e+00   2021-10-29 11:55
# 177  4.747371e+09   2020-08-26 12:28
# 178  4.747371e+09   2020-08-26 12:28
# 179  4.747371e+09   2020-08-26 12:28
# 180  1.848849e+07                NaN
# 181  1.640272e+06   2020-09-04 20:54
# 182  0.000000e+00   2020-08-10 20:26
# 183  1.039640e+09   2019-08-09 05:36
# 189  0.000000e+00                NaN
# 190  0.000000e+00                NaN
# 191  1.068693e+09   2021-08-04 23:37
# 192  5.306277e+06   2020-12-21 03:58
# 196  5.505306e+08   2020-12-18 03:00
# 197  5.505306e+08   2020-12-18 03:00
# 200  4.226855e+08   2020-06-02 19:03
# 202  1.773244e+07                NaN
# 203  7.645819e+09   2020-09-14 18:11
# 204  7.645819e+09   2020-09-14 18:11
# 205  7.645819e+09   2020-09-14 18:11
# 206  1.012955e+07   2020-12-13 12:05
# 207  4.729026e+06                NaN
# 208  3.695177e+06                NaN
# 211  6.770055e+07   2021-02-11 13:50
# 215  3.783931e+07                NaN
# 216  4.532528e+08                NaN
# 217  5.602964e+05   2021-02-24 11:43
# 218  5.980396e+06   2021-02-21 23:50
# 219  1.444711e+06   2020-09-18 15:17
# 220  3.248661e+07   2021-04-17 12:20
# 221  4.179206e+09   2020-07-17 08:01
# 225  1.800164e+05   2020-10-21 00:33

# %% [markdown]
# ### Step 5: Create the current age column

# %%
#Current Date
now = pd.Timestamp('now')
finalTable['LaunchDate'] = pd.to_datetime(finalTable['LaunchDate'], format="%Y-%m-%d %H:%M")    
finalTable['age'] = (now - finalTable['LaunchDate']).astype('<m8[M]')    #Age in months
finalTable = finalTable.drop_duplicates(subset=['appId'], keep='first')
finalTable
# Out:
#                       appId                     tags                    name  \
# 0                  aave-amm                  lending                Aave AMM
# 1        aave-safety-module           liquidity-pool      Aave Safety Module
# 2                      aave                  lending                    Aave
# 3                   aave-v2                  lending                 Aave V2
# 4                aavegotchi         yield-aggregator              Aavegotchi
# 5               abracadabra                  lending             Abracadabra
# 7                  alchemix                  lending                Alchemix
# 8                    alkemi                  lending          Alkemi Network
# 9          alpha-tokenomics          elastic-finance        Alpha Tokenomics
# 10                 alpha-v1                  lending                   Alpha
# 11                 alpha-v2                  lending                Alpha V2
# 16                      apy         yield-aggregator                     APY
# 17                     arcx         yield-aggregator                    ARCx
# 18                    armor                insurance                   Armor
# 20               b-protocol                  lending              B.Protocol
# 21                   badger         yield-aggregator                  Badger
# 22              balancer-v1           liquidity-pool                Balancer
# 23              balancer-v2           liquidity-pool             Balancer V2
# 24                   bancor           liquidity-pool                  Bancor
# 25                      bao           liquidity-pool                     Bao
# 26               barnbridge  tokenized-risk-protocol              BarnBridge
# 27   barnbridge-smart-yield  tokenized-risk-protocol  BarnBridge Smart Yield
# 34                     bent                      NaN            Bent Finance
# 39                 compound                  lending                Compound
# 40                   convex         yield-aggregator                  Convex
# 41                    cream                  lending                   Cream
# 42                  cryptex           liquidity-pool                 Cryptex
# 43                    curve           liquidity-pool                   Curve
# 48                defi-swap           liquidity-pool               DeFi Swap
# 52                defisaver                  lending               DefiSaver
# 53                derivadex              derivatives               DerivaDEX
# 54                deversifi                 exchange               DeversiFi
# 55                   dforce         yield-aggregator                  dForce
# 57                   dhedge         asset-management                  dHedge
# 59                     dodo           liquidity-pool                    Dodo
# 60                    dopex                  options                   Dopex
# 61                     dydx           margin-trading                    dYdX
# 62                    88mph                  lending                   88mph
# 63                 88mph-v3                  lending                88mph V3
# 64                  element                  lending                 Element
# 70                      fei         asset-management                     Fei
# 71           float-protocol         asset-management                   Float
# 73                     frax         asset-management                    Frax
# 76             governor-dao           liquidity-pool            Governor DAO
# 78                      gro                  lending                     Gro
# 79                  harvest         yield-aggregator                 Harvest
# 81                    hegic                  options                   Hegic
# 83                      hop                      NaN                     Hop
# 84          hundred-finance                  lending         Hundred Finance
# 85                     idle         yield-aggregator                    Idle
# 86                 illuvium                   gaming                Illuvium
# 87               index-coop            asset-indexes              Index Coop
# 88                  indexed             fund-manager                 Indexed
# 89                  inverse         yield-aggregator         Inverse Finance
# 90                     iron          elastic-finance                    Iron
# 92                iron-bank                  lending               Iron Bank
# 95             keep-network             fund-manager            Keep Network
# 96               keeper-dao         yield-aggregator               KeeperDAO
# 98                 klondike             fund-manager                Klondike
# 104                 liquity                  lending                 Liquity
# 105               looksrare                      NaN               LOOKSRARE
# 106                loopring                 exchange                Loopring
# 108                    lyra                  options                    Lyra
# 110                   maple                  lending                   Maple
# 111                  mirror           liquidity-pool                  Mirror
# 112               mooniswap                 exchange               Mooniswap
# 114                 mstable         asset-management                 mStable
# 116            nexus-mutual                      NaN            Nexus Mutual
# 119                   nft20                      NaN                   NFT20
# 120                    nftx                      NaN                    NFTX
# 121           nsure-network                insurance                   Nsure
# 122                 olympus          elastic-finance                 Olympus
# 123                    ondo         yield-aggregator            Ondo Finance
# 124                   1inch                 exchange                   1inch
# 125                     onx                  lending                     OnX
# 126           opium-network              derivatives                   Opium
# 127                    opyn                  options                    Opyn
# 128                  origin               stablecoin                  Origin
# 129          orion-protocol                 exchange                   Orion
# 135      perpetual-protocol                 exchange               Perpetual
# 136                  pickle         yield-aggregator                  Pickle
# 137                 pie-dao           liquidity-pool                  PieDAO
# 140            pooltogether          no-loss-lottery            PoolTogether
# 141         pooltogether-v4          no-loss-lottery         PoolTogether V4
# 142                popsicle           liquidity-pool                Popsicle
# 143               powerpool            asset-bundles               PowerPool
# 147                 railgun                 exchange                 Railgun
# 149                    rari             fund-manager            Rari Capital
# 150               rari-fuse           liquidity-pool               Rari Fuse
# 153         redacted-cartel          elastic-finance         Redacted Cartel
# 154                reflexer                  lending                Reflexer
# 156                  ribbon         yield-aggregator                  Ribbon
# 157               ribbon-v2         yield-aggregator               Ribbon V2
# 159                 sablier                  payroll                 Sablier
# 160                  saddle           liquidity-pool                  Saddle
# 163              shapeshift                 exchange              Shapeshift
# 165                   shell           liquidity-pool                   Shell
# 169                snowswap           liquidity-pool                SnowSwap
# 173                   squid          elastic-finance                SquidDao
# 177               sushiswap           liquidity-pool               Sushiswap
# 178      sushiswap-bentobox                  lending      SushiSwap BentoBox
# 179         sushiswap-kashi                  lending         SushiSwap Kashi
# 180                   swapr           liquidity-pool                   Swapr
# 181                  swerve           liquidity-pool                  Swerve
# 182                  synlev           liquidity-pool                  SynLev
# 183               synthetix           liquidity-pool               Synthetix
# 189               the-graph           liquidity-pool               The Graph
# 191                 tokemak           liquidity-pool                 Tokemak
# 192                tokenlon         asset-management                Tokenlon
# 196            tornado-cash           infrastructure            Tornado Cash
# 200                  truefi                  lending                  TrueFi
# 202                  unagii         yield-aggregator                  Unagii
# 203                 uniswap                 exchange                 Uniswap
# 204              uniswap-v2           liquidity-pool              Uniswap V2
# 205              uniswap-v3           liquidity-pool              Uniswap V3
# 206                    unit                  lending                    Unit
# 207                universe                      NaN                Universe
# 211                  vesper         yield-aggregator                  Vesper
# 215                 wepiggy                  lending                 WePiggy
# 216              wonderland          elastic-finance              Wonderland
# 217                  xsigma           liquidity-pool                  xSigma
# 218                  xtoken         asset-management                  xToken
# 219                     yam         asset-management                     Yam
# 220                   yaxis         yield-aggregator                   yAxis
# 221                   yearn         yield-aggregator                   Yearn
# 225                    zlot         yield-aggregator                    zLOT
#
#        categorySolace      SolaceID  \
# 0             lending          aave
# 1      liquidity-pool          aave
# 2             lending          aave
# 3             lending          aave
# 4    yield-aggregator    aavegotchi
# 5             lending   abracadabra
# 7             lending      alchemix
# 8             lending        alkemi
# 9               other         alpha
# 10            lending         alpha
# 11            lending         alpha
# 16   yield-aggregator           apy
# 17   yield-aggregator          arcx
# 18              other         armor
# 20            lending    b.protocol
# 21   yield-aggregator        badger
# 22     liquidity-pool      balancer
# 23     liquidity-pool      balancer
# 24     liquidity-pool        bancor
# 25     liquidity-pool           bao
# 26              other    barnbridge
# 27              other    barnbridge
# 34            unknown          bent
# 39            lending      compound
# 40   yield-aggregator        convex
# 41            lending         cream
# 42     liquidity-pool       cryptex
# 43     liquidity-pool         curve
# 48     liquidity-pool          defi
# 52            lending     defisaver
# 53              other     derivadex
# 54           exchange     deversifi
# 55   yield-aggregator        dforce
# 57   asset-management        dhedge
# 59     liquidity-pool          dodo
# 60              other         dopex
# 61              other          dydx
# 62            lending         88mph
# 63            lending         88mph
# 64            lending       element
# 70   asset-management           fei
# 71   asset-management         float
# 73   asset-management          frax
# 76     liquidity-pool      governor
# 78            lending           gro
# 79   yield-aggregator       harvest
# 81              other         hegic
# 83            unknown           hop
# 84            lending       hundred
# 85   yield-aggregator          idle
# 86              other      illuvium
# 87              other         index
# 88              other       indexed
# 89   yield-aggregator       inverse
# 90              other          iron
# 92            lending          iron
# 95              other          keep
# 96   yield-aggregator     keeperdao
# 98              other      klondike
# 104           lending       liquity
# 105           unknown     looksrare
# 106          exchange      loopring
# 108             other          lyra
# 110           lending         maple
# 111    liquidity-pool        mirror
# 112          exchange     mooniswap
# 114  asset-management       mstable
# 116           unknown         nexus
# 119           unknown         nft20
# 120           unknown          nftx
# 121             other         nsure
# 122             other       olympus
# 123  yield-aggregator          ondo
# 124          exchange         1inch
# 125           lending           onx
# 126             other         opium
# 127             other          opyn
# 128             other        origin
# 129          exchange         orion
# 135          exchange     perpetual
# 136  yield-aggregator        pickle
# 137    liquidity-pool        piedao
# 140             other  pooltogether
# 141             other  pooltogether
# 142    liquidity-pool      popsicle
# 143             other     powerpool
# 147          exchange       railgun
# 149             other          rari
# 150    liquidity-pool          rari
# 153             other      redacted
# 154           lending      reflexer
# 156  yield-aggregator        ribbon
# 157  yield-aggregator        ribbon
# 159             other       sablier
# 160    liquidity-pool        saddle
# 163          exchange    shapeshift
# 165    liquidity-pool         shell
# 169    liquidity-pool      snowswap
# 173             other      squiddao
# 177    liquidity-pool     sushiswap
# 178           lending     sushiswap
# 179           lending     sushiswap
# 180    liquidity-pool         swapr
# 181    liquidity-pool        swerve
# 182    liquidity-pool        synlev
# 183    liquidity-pool     synthetix
# 189    liquidity-pool           the
# 191    liquidity-pool       tokemak
# 192  asset-management      tokenlon
# 196             other       tornado
# 200           lending        truefi
# 202  yield-aggregator        unagii
# 203          exchange       uniswap
# 204    liquidity-pool       uniswap
# 205    liquidity-pool       uniswap
# 206           lending          unit
# 207           unknown      universe
# 211  yield-aggregator        vesper
# 215           lending       wepiggy
# 216             other    wonderland
# 217    liquidity-pool        xsigma
# 218  asset-management        xtoken
# 219  asset-management           yam
# 220  yield-aggregator         yaxis
# 221  yield-aggregator         yearn
# 225  yield-aggregator          zlot
#
#                                                address  symbol audits  \
# 0           0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9    AAVE      2
# 1           0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9    AAVE      2
# 2           0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9    AAVE      2
# 3           0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9    AAVE      2
# 4           0x3f382dbd960e3a9bbceae22651e88158d2791550    GHST      2
# 5           0x090185f2135308bad17527004364ebcc2d37e5f6   SPELL      2
# 7           0xdbdb4d16eda451d0503b854cf79d55697f90c8df    ALCX      2
# 8           0x6c16119b20fa52600230f074b349da3cb861a7e3     ALK      2
# 9           0xa1faa113cbe53436df28ff0aee54275c13b40975   ALPHA      2
# 10          0xa1faa113cbe53436df28ff0aee54275c13b40975   ALPHA      2
# 11          0xa1faa113cbe53436df28ff0aee54275c13b40975   ALPHA      2
# 16          0x95a4492f028aa1fd432ea71146b433e7b4446611     APY      2
# 17      eth:0x1321f1f1aa541a56c31682c57b80ecfccd9bb288    ARCx      0
# 18          0x1337def16f9b486faed0293eb623dc8395dfe46a   ARMOR      0
# 20          0xbbbbbbb5aa847a2003fbc6b5c16df0bd1e725f61    BPRO      2
# 21          0x3472a5a71965499acd81997a54bba8d852c6e53d  BADGER      2
# 22          0xba100000625a3754423978a60c9317c58a424e3d     BAL      2
# 23          0xba100000625a3754423978a60c9317c58a424e3d     BAL      2
# 24          0x1f573d6fb3f13d689ff844b4ce37794d79a7ff1
x1f9840a85d5af5bf1d1762f925bdaddc4201f984     UNI      2
# 204         0x1f9840a85d5af5bf1d1762f925bdaddc4201f984     UNI      2
# 205         0x1f9840a85d5af5bf1d1762f925bdaddc4201f984     UNI      2
# 206         0x92e187a03b6cd19cb6af293ba17f2745fd2357d5    DUCK      2
# 207                                               None       -      2
# 211         0x1b40183efb4dd766f11bda7a7c3ad8982e998421     VSP      2
# 215         0x6f620ec89b8479e97a6985792d0c64f237566746     WPC      2
# 216    avax:0xb54f16fb19478766a268f172c9480f8da1a7c9c3    TIME      0
# 217         0x7777777777697cfeecf846a76326da79cc606517     SIG      0
# 218         0x7f3edcdd180dbe4819bd98fee8929b5cedb3adeb     XTK      2
# 219         0x0aacfbec6a24756c20d41914f2caba817c0d8521     YAM      3
# 220         0x0ada190c81b814548ddc2f6adc4a689ce7c1fe73   YAXIS      2
# 221         0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e     YFI      1
# 225         0xa8e7ad77c60ee6f30bac54e2e7c0617bd7b5a03e    zLot      0
#
#                                                 chains            oracles  \
# 0                       [Ethereum, Avalanche, Polygon]        [Chainlink]
# 1                       [Ethereum, Avalanche, Polygon]        [Chainlink]
# 2                       [Ethereum, Avalanche, Polygon]        [Chainlink]
# 3                       [Ethereum, Avalanche, Polygon]        [Chainlink]
# 4                                  [Polygon, Ethereum]                NaN
# 5              [Ethereum, Arbitrum, Fantom, Avalanche]        [Chainlink]
# 7                                           [Ethereum]                 []
# 8                                           [Ethereum]        [Chainlink]
# 9                       [Avalanche, Ethereum, Binance]  [Band, Chainlink]
# 10                      [Avalanche, Ethereum, Binance]  [Band, Chainlink]
# 11                      [Avalanche, Ethereum, Binance]  [Band, Chainlink]
# 16                                          [Ethereum]        [Chainlink]
# 17                                          [Ethereum]                NaN
# 18                                          [Ethereum]                NaN
# 20                        [Ethereum, Fantom, Arbitrum]        [Chainlink]
# 21                       [Ethereum, Arbitrum, Binance]                 []
# 22                       [Ethereum, Polygon, Arbitrum]                NaN
# 23                       [Ethereum, Polygon, Arbitrum]                NaN
# 24                                          [Ethereum]        [Chainlink]
# 25                                    [Ethereum, xDai]                NaN
# 26                      [Ethereum, Polygon, Avalanche]        [Chainlink]
# 27                      [Ethereum, Polygon, Avalanche]        [Chainlink]
# 34                                          [Ethereum]                NaN
# 39                                          [Ethereum]        [Chainlink]
# 40                                          [Ethereum]                NaN
# 41                        [Binance, Ethereum, Polygon]  [Chainlink, Band]
# 42                                          [Ethereum]        [Chainlink]
# 43   [Ethereum, Avalanche, Fantom, Polygon, Arbitru...                 []
# 48                                          [Ethereum]                NaN
# 52                                          [Ethereum]                NaN
# 53                                          [Ethereum]                NaN
# 54                                          [Ethereum]                NaN
# 55             [Ethereum, Arbitrum, Binance, Optimism]  [Chainlink, Band]
# 57                       [Ethereum, Polygon, Optimism]                NaN
# 59      [Ethereum, Binance, Polygon, Aurora, Arbitrum]        [Chainlink]
# 60            [Arbitrum, Avalanche, Binance, Ethereum]                NaN
# 61                                          [Ethereum]        [Chainlink]
# 62              [Ethereum, Fantom, Polygon, Avalanche]        [Chainlink]
# 63              [Ethereum, Fantom, Polygon, Avalanche]        [Chainlink]
# 64                                          [Ethereum]                NaN
# 70                                          [Ethereum]        [Chainlink]
# 71                                          [Ethereum]                NaN
# 73                                  [Ethereum, Fantom]  [Chainlink, TWAP]
# 76                                          [Ethereum]                NaN
# 78                               [Ethereum, Avalanche]                NaN
# 79                        [Ethereum, Polygon, Binance]                NaN
# 81                                          [Ethereum]                NaN
# 83       [Ethereum, Arbitrum, Polygon, Optimism, xDai]                NaN
# 84    [Fantom, Arbitrum, Harmony, Moonriver, Ethereum]        [Chainlink]
# 85                                 [Ethereum, Polygon]        [Chainlink]
# 86                                          [Ethereum]                NaN
# 87                                          [Ethereum]                NaN
# 88                                          [Ethereum]                NaN
# 89                                          [Ethereum]                NaN
# 90                       [Ethereum, Avalanche, Fantom]        [Chainlink]
# 92                       [Ethereum, Avalanche, Fantom]        [Chainlink]
# 95                                          [Ethereum]            [Maker]
# 96                                          [Ethereum]                NaN
# 98                                          [Ethereum]                NaN
# 104                                         [Ethereum]        [Chainlink]
# 105                                         [Ethereum]                NaN
# 106                                         [Ethereum]  [Chainlink, Band]
# 108                               [Optimism, Ethereum]        [Chainlink]
# 110                                         [Ethereum]                NaN
# 111                                  [Terra, Ethereum]             [Band]
# 112                                         [Ethereum]                NaN
# 114                                [Ethereum, Polygon]                NaN
# 116                                         [Ethereum]        [Chainlink]
# 119                                [Ethereum, Polygon]                NaN
# 120                                         [Ethereum]                NaN
# 121                                         [Ethereum]        [Chainlink]
# 122                                         [Ethereum]                NaN
# 123                                         [Ethereum]                NaN
# 124                                         [Ethereum]        [Chainlink]
# 125                                         [Ethereum]                NaN
# 126                       [Ethereum, Polygon, Binance]                NaN
# 127                              [Ethereum, Avalanche]        [Chainlink]
# 128                                         [Ethereum]                NaN
# 129                                [Ethereum, Binance]                NaN
# 135                         [xDai, Optimism, Ethereum]        [Chainlink]
# 136  [Ethereum, Arbitrum, Aurora, Polygon, Moonrive...                NaN
# 137                                         [Ethereum]                NaN
# 140      [Ethereum, Polygon, Celo, Avalanche, Binance]        [Chainlink]
# 141      [Ethereum, Polygon, Celo, Avalanche, Binance]        [Chainlink]
# 142                        [Fantom, Binance, Ethereum]                NaN
# 143                                [Ethereum, Binance]                NaN
# 147                       [Ethereum, Binance, Polygon]                NaN
# 149                                         [Ethereum]        [Chainlink]
# 150                                         [Ethereum]        [Chainlink]
# 153                                         [Ethereum]                NaN
# 154                                         [Ethereum]        [Chainlink]
# 156              [Ethereum, Avalanche, Aurora, Solana]                NaN
# 157              [Ethereum, Avalanche, Aurora, Solana]                NaN
# 159                                         [Ethereum]                NaN
# 160             [Ethereum, Fantom, Arbitrum, Optimism]                NaN
# 163                                         [Ethereum]                NaN
# 165                                         [Ethereum]                NaN
# 169                                [Ethereum, Polygon]        [Chainlink]
# 173                                         [Ethereum]                NaN
# 177  [Ethereum, Arbitrum, Polygon, Fantom, Avalanch...                 []
# 178  [Ethereum, Arbitrum, Polygon, Fantom, Avalanch...                 []
# 179  [Ethereum, Arbitrum, Polygon, Fantom, Avalanch...                 []
# 180                         [xDai, Arbitrum, Ethereum]                NaN
# 181                                         [Ethereum]                NaN
# 182                                         [Ethereum]                NaN
# 183                               [Ethereum, Optimism]        [Chainlink]
# 189                                [Ethereum, Polygon]                NaN
# 191                                         [Ethereum]                NaN
# 192                                         [Ethereum]                NaN
# 196                                         [Ethereum]                 []
# 200                                         [Ethereum]                NaN
# 202                                         [Ethereum]                NaN
# 203            [Ethereum, Polygon, Arbitrum, Optimism]                 []
# 204            [Ethereum, Polygon, Arbitrum, Optimism]                 []
# 205            [Ethereum, Polygon, Arbitrum, Optimism]                 []
# 206                                         [Ethereum]                NaN
# 207                                [Ethereum, Polygon]                NaN
# 211                                         [Ethereum]        [Chainlink]
# 215  [Ethereum, Binance, OKExChain, Arbitrum, Optim...        [Chainlink]
# 216                              [Avalanche, Ethereum]                NaN
# 217                                         [Ethereum]                NaN
# 218                                         [Ethereum]                NaN
# 219                                         [Ethereum]                NaN
# 220                                         [Ethereum]                NaN
# 221                                 [Ethereum, Fantom]                NaN
# 225                                         [Ethereum]                NaN
#
#               tvl          LaunchDate   age
# 0    1.359565e+10 2020-09-24 18:06:00  16.0
# 1    1.359565e+10 2020-09-24 18:06:00  16.0
# 2    1.359565e+10 2020-09-24 18:06:00  16.0
# 3    1.359565e+10 2020-09-24 18:06:00  16.0
# 4    1.754204e+07                 NaT   NaN
# 5    3.130727e+09 2021-05-17 22:10:00   8.0
# 7    9.604898e+08 2021-02-27 04:28:00  11.0
# 8    9.860368e+06 2021-09-02 17:35:00   5.0
# 9    8.278031e+08 2020-09-27 09:10:00  16.0
# 10   8.278031e+08 2020-09-27 09:10:00  16.0
# 11   8.278031e+08 2020-09-27 09:10:00  16.0
# 16   1.910854e+07 2020-11-05 02:58:00  15.0
# 17   0.000000e+00                 NaT   NaN
# 18   5.151683e+08 2021-01-22 21:23:00  12.0
# 20   2.087972e+08 2021-04-22 07:24:00   9.0
# 21   8.837397e+08 2020-11-28 17:32:00  14.0
# 22   3.326251e+09 2020-06-20 01:32:00  19.0
# 23   3.326251e+09 2020-06-20 01:32:00  19.0
# 24   1.166352e+09 2017-06-10 16:02:00  56.0
# 25   4.841032e+07 2020-12-01 19:26:00  14.0
# 26   1.315753e+07 2020-09-07 15:55:00  17.0
# 27   1.315753e+07 2020-09-07 15:55:00  17.0
# 34   6.219070e+07                 NaT   NaN
# 39   7.240576e+09 2020-03-04 00:08:00  23.0
# 40   1.365008e+10 2021-05-17 09:08:00   9.0
# 41   4.483840e+08 2020-08-04 15:06:00  18.0
# 42   9.852366e+06 2021-04-06 04:21:00  10.0
# 43   1.976971e+10 2020-08-12 22:17:00  18.0
# 48   5.510571e+07 2018-11-14 09:11:00  39.0
# 52   4.300131e+08                 NaT   NaN
# 53   3.104471e+07 2020-12-04 02:32:00  14.0
# 149  7.627971e+08 2020-10-20 16:51:00  15.0
# 150  7.627971e+08 2020-10-20 16:51:00  15.0
# 153  3.400411e+07                 NaT   NaN
# 154  1.789547e+08 2021-02-13 12:48:00  12.0
# 156  2.066420e+08 2021-05-24 13:12:00   8.0
# 157  2.066420e+08 2021-05-24 13:12:00   8.0
# 159  2.641545e+08                 NaT   NaN
# 160  2.531374e+08                 NaT   NaN
# 163  0.000000e+00 2019-03-26 22:24:00  34.0
# 165  1.588842e+07                 NaT   NaN
# 169  2.140848e+06 2020-10-08 07:37:00  16.0
# 173  0.000000e+00 2021-10-29 11:55:00   3.0
# 177  4.747371e+09 2020-08-26 12:28:00  17.0
# 178  4.747371e+09 2020-08-26 12:28:00  17.0
# 179  4.747371e+09 2020-08-26 12:28:00  17.0
# 180  1.848849e+07                 NaT   NaN
# 181  1.640272e+06 2020-09-04 20:54:00  17.0
# 182  0.000000e+00 2020-08-10 20:26:00  18.0
# 183  1.039640e+09 2019-08-09 05:36:00  30.0
# 189  0.000000e+00                 NaT   NaN
# 191  1.068693e+09 2021-08-04 23:37:00   6.0
# 192  5.306277e+06 2020-12-21 03:58:00  13.0
# 196  5.505306e+08 2020-12-18 03:00:00  13.0
# 200  4.226855e+08 2020-06-02 19:03:00  20.0
# 202  1.773244e+07                 NaT   NaN
# 203  7.645819e+09 2020-09-14 18:11:00  17.0
# 204  7.645819e+09 2020-09-14 18:11:00  17.0
# 205  7.645819e+09 2020-09-14 18:11:00  17.0
# 206  1.012955e+07 2020-12-13 12:05:00  14.0
# 207  4.729026e+06                 NaT   NaN
# 211  6.770055e+07 2021-02-11 13:50:00  12.0
# 215  3.783931e+07                 NaT   NaN
# 216  4.532528e+08                 NaT   NaN
# 217  5.602964e+05 2021-02-24 11:43:00  11.0
# 218  5.980396e+06 2021-02-21 23:50:00  11.0
# 219  1.444711e+06 2020-09-18 15:17:00  16.0
# 220  3.248661e+07 2021-04-17 12:20:00   9.0
# 221  4.179206e+09 2020-07-17 08:01:00  18.0
# 225  1.800164e+05 2020-10-21 00:33:00  15.0

# %% [markdown]
# ### Step 6: Creating excel table and formatting

# %%
writer = pd.ExcelWriter('../temporalDB/TemporalDataset.xlsx', engine='xlsxwriter')

finalTable.to_excel(writer, sheet_name='TemporalData', startrow=1, header=False, index=False)

workbook = writer.book
worksheet = writer.sheets['TemporalData']

(max_row, max_col) = finalTable.shape

#Column Headers
column_settings = []
for header in finalTable.columns:
    column_settings.append({'header': header})

# Add the table.
worksheet.add_table(0, 0, max_row, max_col - 1, {'columns': column_settings})

# Make the columns wider for clarity.
worksheet.set_column(0, max_col - 1, 12)
worksheet.set_column('B:B', 40)
worksheet.set_column('E:E', 40)
worksheet.set_column('H:H', 40)
worksheet.set_column('K:K', 40)
worksheet.set_column('I:I', 40)
worksheet.set_column('C:C', 40)
worksheet.set_column('D:D', 40)


writer.save()

# %% [markdown]
# ### Step 7: Deploy to AWS *WIP

# %% [markdown]
# ### Step 8: Automatic updates *WIP
